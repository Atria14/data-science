# %% [markdown]
# <a href="https://colab.research.google.com/github/Atria14/data-science/blob/main/IT_work_data_analyse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
job = pd.read_csv('IT_job.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37787 entries, 0 to 37786
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      37787 non-null  object
#  1   City                       37787 non-null  object
#  2   Country_code               37754 non-null  object
#  3   Marker_icon                37787 non-null  object
#  4   Workplace_type             37787 non-null  object
#  5   Experience_level           37787 non-null  object
#  6   Published_at               37787 non-null  object
#  7   Remote_interview           37787 non-null  bool
#  8   Remote                     37787 non-null  bool
#  9   Open_to_hire_Ukrainians    32585 non-null  object
#  10  Company_size_from          37732 non-null  object
#  11  Company_size_to            37748 non-null  object
#  12  if_permanent               37787 non-null  bool
# ...

# %%
job.describe()
# Out:
#        salary_from_permanent  salary_to_permanent  salary_from_b2b  \
# count           24007.000000         24007.000000     24007.000000
# mean             4613.176073          6636.659532     13431.149111
# std              7021.674064          9870.964401      8619.690946
# min                 0.000000             0.000000         0.000000
# 25%                 0.000000             0.000000      8000.000000
# 50%                 0.000000             0.000000     14000.000000
# 75%              9800.000000         15000.000000     19000.000000
# max             60951.219512        100000.000000    113246.500000
#
#        salary_to_b2b  salary_from_mandate  salary_to_mandate  \
# count   24007.000000         24007.000000       24007.000000
# mean    18696.479947            95.059298         141.435576
# std     11119.731993          1064.025950        1562.624642
# min         0.000000             0.000000           0.000000
# ...

# %%
job.head()
# Out:
#                                Title       City Country_code Marker_icon  \
# 0  Senior Frontend Software Engineer     London           GB  javascript
# 1               Sr. Backend Engineer     Berlin           DE        java
# 2               Sr. Backend Engineer   Katowice           PL        java
# 3               Sr. Backend Engineer     London           GB        java
# 4     Python Developer (4 days/week)  Białystok           PL      python
#
#   Workplace_type Experience_level              Published_at  Remote_interview  \
# 0         remote           senior  2022-07-31T11:00:14.548Z              True
# 1         remote           senior  2022-07-07T10:25:00.000Z              True
# 2         remote           senior  2022-05-31T11:32:00.000Z              True
# 3         remote           senior  2022-05-25T17:06:36.442Z              True
# 4         remote              mid  2022-06-30T14:57:00.000Z              True
#
# ...

# %%
job_PL = job[job.Country_code == 'PL']
job_PL
# Out:
#                                             Title       City Country_code  \
# 2                            Sr. Backend Engineer   Katowice           PL
# 4                  Python Developer (4 days/week)  Białystok           PL
# 5                  Python Developer (4 days/week)     Kraków           PL
# 6      Mid Full-stack Engineer (React/TypeScript)   Warszawa           PL
# 15                        Senior Backend Engineer   Warszawa           PL
# ...                                           ...        ...          ...
# 24002              Tech Lead with Computer Vision     Kraków           PL
# 24003                       iOS Engineer, ML Team     Kraków           PL
# 24004                              Data Architect     Kraków           PL
# 24005          Delivery Manager, Payments Systems     Kraków           PL
# 24006                 Senior/Lead Search Engineer     Kraków           PL
#
#         Marker_icon Workplace_type Experience_level              Published_at  \
# ...

# %%
job_PL.Marker_icon.value_counts()
# Out:
# javascript      4905
# java            3572
# testing         2750
# net             2350
# devops          2101
# support         2014
# data            1960
# admin           1910
# pm              1812
# php             1707
# python          1676
# mobile          1470
# analytics       1260
# architecture    1224
# other           1216
# c               1107
# ux               734
# security         569
# erp              565
# ruby             399
# html             330
# go               264
# game             220
# scala            143
# Name: Marker_icon, dtype: int64

# %%
job_PL.Marker_icon.value_counts().plot(kind = 'bar')

# %%
job_PL.Experience_level.value_counts()
# Out:
# mid       12439
# senior     8415
# junior     2299
# Name: Experience_level, dtype: int64

# %%
# sprawdzenie ile w sumie jest rekordów spełniających kryteria
# data, junior i skills SQL
job_PL[(job_PL.Marker_icon == 'data') & (job_PL.Experience_level == 'junior') & (job_PL.skills_name_0 == 'SQL') | 
       (job_PL.skills_name_1 == 'SQL') | (job_PL.skills_name_2 == 'SQL')]
# Out:
#                                           Title      City Country_code  \
# 127                       Banking BI/DW Analyst  Warszawa           PL
# 151                    Senior Database Engineer    Gdańsk           PL
# 155                Data Engineer (level Senior)    Gdańsk           PL
# 167                        Senior Data Engineer   Wrocław           PL
# 347              Integrations Software Engineer    Kraków           PL
# ...                                         ...       ...          ...
# 23905           Data Annotation Project Manager    Gdańsk           PL
# 23921               Data Engineer - Allegro Pay  Warszawa           PL
# 23922  Senior Data Engineer (.NET)- Allegro Pay  Warszawa           PL
# 23998                  Digital Data Analyst, AI    Kraków           PL
# 24004                            Data Architect    Kraków           PL
#
#         Marker_icon Workplace_type Experience_level              Published_at  \
# ...

# %%
SQL_job = job_PL[(job_PL.Experience_level == 'junior') & (job_PL.skills_name_0 == 'SQL') | 
       (job_PL.skills_name_1 == 'SQL') | (job_PL.skills_name_2 == 'SQL')]

# %%
SQL_job_1 = SQL_job.drop(columns = ['currency_exchange_rate', 'salary_to_mandate','salary_from_other', 'salary_from_mandate', 'if_other', 'salary_to_other','salary_currency_mandate', 'salary_currency_other', 'Country_code', 
                                    'Open_to_hire_Ukrainians', 'Company_size_from', 'Company_size_to'])
SQL_job_1.head(2).T
# Out:
#                                                 127                       151
# Title                         Banking BI/DW Analyst  Senior Database Engineer
# City                                       Warszawa                    Gdańsk
# Marker_icon                                    data                      data
# Workplace_type                               remote                    remote
# Experience_level                                mid                    senior
# Published_at               2022-06-29T08:27:00.000Z  2022-09-30T13:00:09.854Z
# Remote_interview                               True                      True
# Remote                                         True                      True
# if_permanent                                  False                      True
# salary_from_permanent                           0.0                 20896.173
# salary_to_permanent                             0.0                 26132.337
# ...

# %%
# obliczenie jaki % ogłoszeń to praca dla juniora z SQL
job_PL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23153 entries, 2 to 24006
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      23153 non-null  object
#  1   City                       23153 non-null  object
#  2   Country_code               23153 non-null  object
#  3   Marker_icon                23153 non-null  object
#  4   Workplace_type             23153 non-null  object
#  5   Experience_level           23153 non-null  object
#  6   Published_at               23153 non-null  object
#  7   Remote_interview           23153 non-null  bool
#  8   Remote                     23153 non-null  bool
#  9   Open_to_hire_Ukrainians    19918 non-null  object
#  10  Company_size_from          23102 non-null  object
#  11  Company_size_to            23122 non-null  object
#  12  if_permanent               23153 non-null  bool
# ...

# %%
entries_PL = job_PL.shape[0]
entries_PL
# Out:
# 23153

# %%
SQL_job_1.info()
entries_SQL = SQL_job_1.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1267 entries, 127 to 24004
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      1267 non-null   object
#  1   City                       1267 non-null   object
#  2   Marker_icon                1267 non-null   object
#  3   Workplace_type             1267 non-null   object
#  4   Experience_level           1267 non-null   object
#  5   Published_at               1267 non-null   object
#  6   Remote_interview           1267 non-null   bool
#  7   Remote                     1267 non-null   bool
#  8   if_permanent               1267 non-null   bool
#  9   salary_from_permanent      1267 non-null   float64
#  10  salary_to_permanent        1267 non-null   float64
#  11  salary_currency_permanent  1267 non-null   object
#  12  if_b2b                     1267 non-null   bool
# ...

# %%
# % wszystkich ogloszeń dla juniora z umiejętnością SQL
entries_SQL / entries_PL * 100
# Out:
# 5.472293007385652

# %%
# ilość rekordów dla Workplace_type == 'remote'
remote = job_PL[job_PL.Workplace_type == 'remote'].shape[0]
remote
# Out:
# 24007

# %%
# ilość rekordów dla wszystkich ogłoszeń z job
all = job.shape[0]
all

# %%
# % ogłoszeń pracy zdalnej
remote/all * 100
# Out:
# 72.09563877202483

# %%
# Out:
# (23153, 35)
